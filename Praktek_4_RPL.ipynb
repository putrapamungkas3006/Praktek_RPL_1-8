# %%
import numpy as np

# %%
class MyLinearRegression:

  def __init__(self, fit_intercept=True):
      self.coef_ = None
      self.intercept_ = None
      self._fit_intercept = fit_intercept

# %%
mlr =MyLinearRegression()

# %%
mlr._fit_intercept
# Out:
# True

# %%
mlr.coef_==None
# Out:
# True

# %%
mlr.intercept_==None
# Out:
# True

# %%
print(mlr)
# Out:
# <__main__.MyLinearRegression object at 0x7c6b34a38100>

# %%
class MyLinearRegression:

  def __init__ (self, fit_intercept=True):
      self.coef_ = None
      self.intercept_ = None
      self._fit_intercept = fit_intercept

  def __repr__(self):
      return "I am a Linear Regression model!"

# %%
mlr = MyLinearRegression()

# %%
print(mlr)
# Out:
# I am a Linear Regression model!

# %%
class MyLinearRegression:

  def __init__(self, fit_intercept=True):
      self.coef_ = None
      self.intercept_ = None
      self._fit_intercept = fit_intercept

  def __repr__(self):
      return "I am a Linear Regression modell"

  def fit(self, x, y):
      """
      Fit model coefficients.

      Arguments:
      X: 10 or 20 numpy array
      y: 10 numpy array
      """

      # check if x is 10 or 20 array
      if len(X.shape) == 1:
          X = X.reshape(-1,1)

      # add bias if fit intercept is True
      if self._fit_intercept:
          X_biased = np.c_[np.ones(X.shape[0]), X]
      else:
          X_biased = X

      #closed form solution
      xTx = np.dot(X_biased.T, X_biased)
      inverse_xTx = np.linalg.inv(xTx)
      xTy = np.dot(X_biased.T, y)
      coef = np.dot(inverse_xTx, xTy)

      # set attributes
      if self._fit_intercept:
          self.intercept_ = coef[0]
          self.coef_ = coef[1:]
      else:
          self.intercept_ = 0
          self.coef_ = coef

# %%
import numpy as np
X = 10 * np.random.random(size=(20, 2))
y = 3.5 * X.T[0] - 1.2 * X.T[1] + 2 * np.random.randn(20)

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots (1,2, figsize=(10,3))

ax[0].scatter(X.T[0],y)
ax[0].set_title("Output vs. first feature")
ax[0].grid(True)
ax[1].scatter(X.T[1],y)
ax[1].set_title("Output vs. second feature")
ax[1].grid(True)
fig.tight_layout()
plt.show()

# %%
mlr = MyLinearRegression()

# %%
print("We have not fitted the data yet. There is no regression coefficients")
print("Regression coefficients:", mlr.coef_)
# Out:
# We have not fitted the data yet. There is no regression coefficients
# Regression coefficients: None

# %%
from sklearn.linear_model import LinearRegression

# Assuming x is your feature matrix (X) and y is your target variable (y)
mlr = LinearRegression()
mlr.fit(X, y)
# Out:
# LinearRegression()

# %%
print("we have fitted the data. We can print the regression coefficients now")
print("Regression coefficients:", mlr.coef_)
# Out:
# we have fitted the data. We can print the regression coefficients now
# Regression coefficients: [ 3.27711501 -1.4010308 ]

# %%
print("The intercept term is given by: ", mlr.intercept_)
# Out:
# The intercept term is given by:  1.7103773127010076

# %%
coef_ = mlr.coef_
y_pred = np.dot(X,coef_)+mlr.intercept_

# %%
plt.scatter(y,y_pred,s=100,alpha=0.75,color='red',edgecolor='k')
plt.plot(y,y,c='k', linestyle='dotted')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

class MyLinearRegression:

    def __init__(self, fit_intercept=True):
        self.coef_ = None
        self.intercept_ = None
        self._fit_intercept = fit_intercept

    def __repr__(self):
        return "I am a Linear Regression model!"

    def fit(self, X, y):
        """
        Fit model coefficients.

        Arguments:
        X: 1D or 2D numpy array
        y: 1D numpy array
        """

        # check if X is 1D or 2D array.
        if len(X.shape) == 1:
            X = X.reshape(-1, 1)

        # add bias if fit intercept is True
        if self._fit_intercept:
            X_biased = np.c_[np.ones(X.shape[0]), X]
        else:
            X_biased = X

        # closed form solution
        xTx = np.dot(X_biased.T, X_biased)
        inverse_xTx = np.linalg.inv(xTx)
        xTy = np.dot(X_biased.T, y)
        coef = np.dot(inverse_xTx, xTy)

        # set attributes
        if self._fit_intercept:
            self.intercept_ = coef[0]
            self.coef_ = coef[1:]
        else:
            self.intercept_ = 0
            self.coef_ = coef

        # Predicted/fitted y
        self.fitted_ = np.dot(X_biased, np.concatenate(([self.intercept_], self.coef_)))

    def plot_fitted(self, reference_line=False):
        """
        Plots fitted values against the true output values from the data

        Arguments:
        reference_line: A Boolean switch to draw a 45-degree reference line on the plot
        """
        plt.title("True vs. fitted values", fontsize=14)
        plt.scatter(y, self.fitted_, s=100, alpha=0.75, color='red', edgecolor="k")
        if reference_line:
            plt.plot(y, y, c='k', linestyle='dotted')
        plt.xlabel("True values")
        plt.ylabel("Fitted values")
        plt.grid(True)
        plt.show()

# %%
# A fresh instance
mlr = MyLinearRegression()
# Fitting with the data
mlr.fit(X, y)

# %%
# call the 'plot_fitted' method
mlr.plot_fitted()

# %%
# we can pass on a switch 'reference_line' to draw a 45-degree reference line on thr plot
mlr.plot_fitted(reference_line=True)

# %%
import numpy as np
import matplotlib.pyplot as plt

class MyLinearRegression:

    def __init__(self, fit_intercept=True):
        self.coef_ = None
        self.intercept_ = None
        self._fit_intercept = fit_intercept

    def __repr__(self):
        return "I am a Linear Regression model!"

    def fit(self, X, y):
        """
        Fit model coefficients.

        Arguments:
        X: 1D or 2D numpy array
        y: 1D numpy array
        """

        # check if X is 1D or 2D array.
        if len(X.shape) == 1:
            X = X.reshape(-1, 1)

        # add bias if fit intercept is True
        if self._fit_intercept:
            X_biased = np.c_[np.ones(X.shape[0]), X]
        else:
            X_biased = X

        # closed form solution
        xTx = np.dot(X_biased.T, X_biased)
        inverse_xTx = np.linalg.inv(xTx)
        xTy = np.dot(X_biased.T, y)
        coef = np.dot(inverse_xTx, xTy)

        # set attributes
        if self._fit_intercept:
            self.intercept_ = coef[0]
            self.coef_ = coef[1:]
        else:
            self.intercept_ = 0
            self.coef_ = coef

        # Predicted/fitted y
        self.fitted_ = np.dot(X_biased, np.concatenate(([self.intercept_], self.coef_)))

    def plot_fitted(self, reference_line=False):
        """
        Plots fitted values against the true output values from the data

        Arguments:
        reference_line: A Boolean switch to draw a 45-degree reference line on the plot
        """
        plt.title("True vs. fitted values", fontsize=14)
        plt.scatter(y, self.fitted_, s=100, alpha=0.75, color='red', edgecolor="k")
        if reference_line:
            plt.plot(y, y, c='k', linestyle='dotted')
        plt.xlabel("True values")
        plt.ylabel("Fitted values")
        plt.grid(True)
        plt.show()

    def predict(self, X):
        """Output model prediction.

        Arguments:
        X: 1D or 2D numpy array
        """
        # check if X is 1D or 2D array
        if len(X.shape) == 1:
            X = X.reshape(-1, 1)
        self.predicted_ = self.intercept_ + np.dot(X, self.coef_)
        return self.predicted_

# %%
num_new_samples = 10
x_new = 10*np.random.random(size=(num_new_samples,2))

# %%
y_new = 3.5*x_new.T[0]-1.2*x_new.T[1]+2*np.random.randn(num_new_samples)

# %%
mlr = MyLinearRegression()

# %%
from sklearn.linear_model import LinearRegression

# Assuming x is your feature matrix (X) and y is your target variable (y)
mlr = LinearRegression()
mlr.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred=mlr.predict(x_new)

# %%
plt.scatter(y_new,y_pred,s=100,alpha=0.75,color="red",edgecolor='k')
plt.plot(y_new,y_new,c='k',linestyle="dotted")
plt.xlabel("True values")
plt.ylabel("Predicted values")
plt.grid(True)
plt.show()
